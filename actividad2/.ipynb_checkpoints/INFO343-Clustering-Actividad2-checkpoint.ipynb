# %% [markdown]
# ## <h1 align="center">Actividad 2: Agrupar datos textuales con el Modelo de Tópicos y el algoritmo Latent Dirichlet Allocation (LDA)</h3>

# %%
# !python -V
# Out:
# Python 3.6.1 :: Anaconda custom (64-bit)

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <h2> Preámbulo</h2>
# <p> Esta actividad se inspira de ejercicios disponibles en los recursos siguientes:<p>
# <ul>
#     <li>Biblioteca <a href="http://scikit-learn.org/stable/install.html/">SciKit-learn</a> de Python</li>
#     <li>Código disponible en  <a href="https://github.com/lda-project/lda/">lda-project</a></li>
# </ul>
# <p> La actividad requiere el uso de Python 3.x y <a href="http://jupyter.org/install">Jupyter Notebook</a>. El código entregado fue probado con Python 3.6.1. Para saber cuál versión de Python usted está utilizando, ejecutar la celda siguiente (está información es importante cuando se necesitará instalar nuevos paquetes.)
# </p>
# </div>

# %% [markdown]
# <div style="border: 2px solid #D24747; background-color:#F8B4B4">
# <h2>Objetivos de la actividad</h2>
# <p>El <b>objetivo general</b> de esta actividad consiste en saber explorar la estructura oculta de un conjunto de datos textuales.</p>
# <p> Comenzaremos por utilizar un  algoritmo de clustering tradicional como Kmeans para explorar datos textuales, considerando la medida tf-idf por cada término presente en cada texto, para caracterizar los textos y construir distancias entre ellos.</p>
# <p>En una segunda fase utilizaremos el <a href="https://drive.google.com/open?id=1rSQPJvRVj0V_IChzspQMRPNwlDTkHYHp"> Modelo Probabilista De Tópicos </a> para descubrir tópicos en los textos. Para ello se utilizará el algoritmo de asignación de tópicos latentes conocido como <a href= "https://drive.google.com/open?id=1BobImO3192hifZPLXowd14gryVAUzBPW">Latent Dirichlet Allocation (LDA)</a>. El enfoque es probabilista, por lo que el resultado del algoritmo es descubrir tópicos en los textos (el número de tópicos es definido por el analista) y asignar una distribución de probabilidad de tópicos en cada texto.</p>  Dependiendo del tamaño de los textos, es también posible agruparlos de acuerdo al tópico con mayor representación en cada uno, lo que permitirá comparar esta metodología con los algoritmos de clustering clásicos.</p> </div>

# %% [markdown]
# <div style="border: 2px solid #D24747; background-color:#F8B4B4">
# <p>En el primer ejemplo se busca encontrar estructuras ocultas en el discurso de Donald Trump. Con este objetivo, vamos a utilizar un dataset de 297 tweets publicados por Donald Trump entre el 5 diciembre 2016 y el 27 de enero 2017 (aproximadamente 1 mes después su elección).</p>
# <p>El primer paso es la lectura de datos: </p></div>

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#Cargar el dataset de tweets
df_tweets = pd.read_csv('datasets/trump_tweets.csv')
df_tweets
# Out:
#                           Date      Time  \
# 0    2016-12-05 13:53:11+00:00  13:53:11
# 1    2016-12-05 16:00:27+00:00  16:00:27
# 2    2016-12-05 23:06:43+00:00  23:06:43
# 3    2016-12-06 13:52:35+00:00  13:52:35
# 4    2016-12-06 16:45:27+00:00  16:45:27
# 5    2016-12-06 19:09:49+00:00  19:09:49
# 6    2016-12-06 19:10:27+00:00  19:10:27
# 7    2016-12-06 21:17:45+00:00  21:17:45
# 8    2016-12-07 03:33:20+00:00   3:33:20
# 9    2016-12-07 12:18:56+00:00  12:18:56
# 10   2016-12-07 18:38:00+00:00  18:38:00
# 11   2016-12-07 19:37:32+00:00  19:37:32
# 12   2016-12-08 00:41:48+00:00   0:41:48
# 13   2016-12-08 01:56:40+00:00   1:56:40
# 14   2016-12-08 21:15:52+00:00  21:15:52
# 15   2016-12-08 22:55:24+00:00  22:55:24
# 16   2016-12-08 23:12:11+00:00  23:12:11
# 17   2016-12-09 03:02:04+00:00   3:02:04
# 18   2016-12-09 19:42:30+00:00  19:42:30
# 19   2016-12-09 22:13:21+00:00  22:13:21
# 20   2016-12-10 03:30:50+00:00   3:30:50
# 21   2016-12-10 11:19:24+00:00  11:19:24
# 22   2016-12-10 11:27:22+00:00  11:27:22
# 23   2016-12-10 12:38:24+00:00  12:38:24
# 24   2016-12-10 14:11:49+00:00  14:11:49
# 25   2016-12-10 14:14:23+00:00  14:14:23
# 26   2016-12-10 18:41:12+00:00  18:41:12
# 27   2016-12-10 19:09:13+00:00  19:09:13
# 28   2016-12-10 19:09:28+00:00  19:09:28
# 29   2016-12-11 12:56:18+00:00  12:56:18
# ..                         ...       ...
# 267  2017-01-22 14:23:17+00:00  14:23:17
# 268  2017-01-23 11:38:16+00:00  11:38:16
# 269  2017-01-24 11:11:47+00:00  11:11:47
# 270  2017-01-24 16:58:06+00:00  16:58:06
# 271  2017-01-24 17:04:01+00:00  17:04:01
# 272  2017-01-24 17:49:17+00:00  17:49:17
# 273  2017-01-25 00:46:57+00:00   0:46:57
# 274  2017-01-25 02:16:19+00:00   2:16:19
# 275  2017-01-25 02:25:40+00:00   2:25:40
# 276  2017-01-25 02:37:48+00:00   2:37:48
# 277  2017-01-25 12:10:01+00:00  12:10:01
# 278  2017-01-25 12:13:46+00:00  12:13:46
# 279  2017-01-25 12:17:01+00:00  12:17:01
# 280  2017-01-25 22:05:59+00:00  22:05:59
# 281  2017-01-26 00:03:33+00:00   0:03:33
# 282  2017-01-26 02:14:56+00:00   2:14:56
# 283  2017-01-26 02:45:32+00:00   2:45:32
# 284  2017-01-26 02:48:25+00:00   2:48:25
# 285  2017-01-26 11:04:24+00:00  11:04:24
# 286  2017-01-26 13:51:46+00:00  13:51:46
# 287  2017-01-26 13:55:03+00:00  13:55:03
# 288  2017-01-26 19:21:17+00:00  19:21:17
# 289  2017-01-26 23:45:28+00:00  23:45:28
# 290  2017-01-26 23:53:37+00:00  23:53:37
# 291  2017-01-27 13:12:52+00:00  13:12:52
# 292  2017-01-27 13:19:10+00:00  13:19:10
# 293  2017-01-27 16:27:02+00:00  16:27:02
# 294  2017-01-27 16:30:29+00:00  16:30:29
# 295  2017-01-27 20:20:15+00:00  20:20:15
# 296  2017-01-27 22:00:47+00:00  22:00:47
#
#                                                  Tweet             Tweetid
# 0    I am thrilled to nominate Dr. @RealBenCarson a...  805772007220645000
# 1    If the press would cover me accurately &amp; h...  805804034309427000
# 2    #ThankYouTour2016 \r\n\r\n12/6- North Carolina...  805911307270713000
# 3    Boeing is building a brand new 747 Air Force O...  806134244384899000
# 4    Join me tonight in Fayetteville, North Carolin...  806177746397306000
# 5    Masa (SoftBank) of Japan has agreed to invest ...  806214078465245000
# 6    Masa said he would never do this had we (Trump...  806214236053667000
# 7    Departing New York with General James 'Mad Dog...  806246271405162000
# 8    A great night in Fayetteville, North Carolina....  806340792247795000
# 9    I will be interviewed on the @TODAYshow at 7:3...  806473064703725000
# 10   We pause today to remember the 2,403 American ...  806568460620857000
# 11   Join me tomorrow in Des Moines, Iowa with Vice...  806583438748815000
# 12   Chuck Jones, who is President of United Steelw...  806660011904614000
# 13   If United Steelworkers 1999 was any good, they...  806678853305384000
# 14   Today we lost a great pioneer of air and space...  806970576359325000
# 15   On my way to Des Moines, Iowa- will see you so...  806995622117122000
# 16   Join me tomorrow! #MAGA \r\n10am- Baton Rouge,...  806999846674698000
# 17   THANK YOU IOWA!\r\n#ThankYouTour2016 https://t...  807057700857188000
# 18   Join me live in Louisiana! Tomorrow, we need y...  807309464705630000
# 19   Thank you Louisiana! Get out &amp; vote for Jo...  807347429062443000
# 20   Thank you Michigan. We are going to bring back...  807427326522884000
# 21   .@RudyGiuliani, one of the finest people I kno...  807545243608420000
# 22   I have NOTHING to do with The Apprentice excep...  807547249681166000
# 23   As a show of support for our Armed Forces, I w...  807565127021109000
# 24   Reports by @CNN that I will be working on The ...  807588632877998000
# 25   A very interesting read. Unfortunately, so muc...  807589280071684000
# 26   RT @TrumpInaugural: Counting down the days unt...  807656426374103000
# 27   October 2015 - thanks Chris Wallace @FoxNewsSu...  807663477322027000
# 28   RT @FoxNewsSunday: Sunday-- our exclusive inte...  807663539116802000
# 29   I will be interviewed today on Fox News Sunday...  807932020236124000
# ..                                                 ...                 ...
# 267  Peaceful protests are a hallmark of our democr...  823174199036542000
# 268  Busy week planned with a heavy focus on jobs a...  823495059010109000
# 269  Will be meeting at 9:00 with top automobile ex...  823850781946343000
# 270  A photo delivered yesterday that will be displ...  823937936056008000
# 271  Great meeting with automobile industry leaders...  823939422743830000
# 272  Signing orders to move forward with the constr...  823950814163140000
# 273  Great meeting with Ford CEO Mark Fields and Ge...  824055927200423000
# 274  Congratulations to @FoxNews for being number o...  824078417213747000
# 275  If Chicago doesn't fix the horrible "carnage" ...  824080766288228000
# 276  Big day planned on NATIONAL SECURITY tomorrow....  824083821889015000
# 277  I will be asking for a major investigation int...  824227824903090000
# 278  even, those registered to vote who are dead (a...  824228768227217000
# 279  I will be making my Supreme Court pick on Thur...  824229586091307000
# 280  I will be interviewed by @DavidMuir tonight at...  824377804590563000
# 281  Beginning today, the United States of America ...  824407390674157000
# 282  As your President, I have no higher duty than ...  824440456813707000
# 283  "@romoabcnews: .@DavidMuir first @POTUS interv...  824448156935081000
# 284  Interview with David Muir of @ABC News in 10 m...  824448880993509000
# 285  Ungrateful TRAITOR Chelsea Manning, who should...  824573698774601000
# 286  The U.S. has a 60 billion dollar trade deficit...  824615820391305000
# 287  of jobs and companies lost. If Mexico is unwil...  824616644370714000
# 288  Spoke at the Congressional @GOP Retreat in Phi...  824698743630995000
# 289  Will be interviewed by @SeanHannity on @FoxNew...  824765229527605000
# 290  Miami-Dade Mayor drops sanctuary policy. Right...  824767281146245000
# 291  Look forward to seeing final results of VoteSt...  824968416486387000
# 292  Mexico has taken advantage of the U.S. for lon...  824970003153842000
# 293  The #MarchForLife is so important. To all of y...  825017279209410000
# 294  .@VP Mike Pence will be speaking at today's #M...  825018149397463000
# 295  Statement on International Holocaust Remembran...  825075972659613000
# 296  Congratulations Secretary Mattis! https://t.co...  825101272982355000
#
# [297 rows x 4 columns]

# %%
#selección de los mensajes
docs = df_tweets["Tweet"].as_matrix()
len(docs)
# Out:
# 297

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
from sklearn.metrics import adjusted_rand_score

stemmer = SnowballStemmer("english")

# load nltk's English stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('english')

# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/mvernier/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/mvernier/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Utilizando Kmeans y tf-idf para realizar un primer agrupamiento de los mensajes
import re
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

vectorizer = TfidfVectorizer(stop_words='english',tokenizer=tokenize_and_stem, ngram_range=(1,3))
X = vectorizer.fit_transform(docs)
num_k = range(1, 20)
inertias = []

for k in num_k:
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters=k)

    # Fit model to samples
    model.fit(X)

    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)



# Plot ks vs inertias
plt.plot(num_k, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(num_k)
plt.show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº1: Explore las clases TfidfVectorizer, CountVectorizer. ¿Qué rol cumplen? ¿Qué tratamiento premilinar de textos se ha hecho en este caso? Qué rol cumple n-gram? </p>
# <p>Pregunta Nº2: A partir del gráfico, justifique el número de clusters para estos datos.</p>
# </div>

# %%
from matplotlib.pylab import hist, show
true_k = 6
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
print("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(true_k):
    cluster_words = np.array(terms)[order_centroids[i, :10]]
    print('Cluster {}: {}'.format(i, ' '.join(cluster_words)))

#Generando algunos gráficos de los resultados
labels = model.predict(X)
plt.scatter(range(297),labels,c=labels)
show()
hist(labels,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9)
show()
# Out:
# Top terms per cluster:
# Cluster 0: https thank thankyoutour2016 join alabama ticket ticket https bring happi wonder
# Cluster 1: great make support america want 20th make america januari make america great america great
# Cluster 2: just talk nation peopl good right bad n't unit togeth
# Cluster 3: state time world vote n't amp wrong say unit state nbcnew
# Cluster 4: interview enjoy tonight foxnew p.m. interview todayshow interview todayshow enjoy todayshow enjoy todayshow abc
# Cluster 5: peopl washington whi presid u.s. american d.c. hack veri washington d.c.

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº2:Explore diversos valores en los parametros n_init y max_iter. ¿Tienen influencia en los resultados? Describa e interprete los resultados.</p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>En lo que sigue se construye un modelo probabilista de tópicos, considerando 9 tópicos (para comparar con Kmeans
#  y el algoritmo LDA estimado con el <a href="https://drive.google.com/open?id=1AoCcmg91Y1yRwM_Ox4Nvf6PGSQ9TybpE">, método de Bayes Variacional</a>, disponible como desarrollo en <a href="http://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html">sklearn-lda.</a></p>
# Previo a ello se utiliza la clase CountVectorizer y su función fit_transform que permite construir una matriz tf (DTM, Document-Term Matrix) que contiene la frecuencia de aparición de cada término del vocabulario en cada texto analizado. En la definición de la clase se especifica que:
# <ol>
#     <li>los términos que  aparecen sólo una vez en algún texto no serán considerados en el vocabulario (min_df=2)</li>
#     <li> los términos que  aparecen en mas del 95% de los textos no serán considerados en el vocabulario (max_df=0.95)</li>
#     <li> se utilizará un conjunto de stop words del inglés </li>
# </ol></div>

# %%
#Aplicando Modelos Probabilistas de Tópicos y LDA
from sklearn.decomposition import LatentDirichletAllocation

def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                stop_words='english',tokenizer=tokenize_and_stem, ngram_range=(1,3))
tf = tf_vectorizer.fit_transform(docs)
diccionario= tf_vectorizer.get_feature_names()


#Estimación de LDA con Bayes Variacional
lda = LatentDirichletAllocation(n_components=true_k, max_iter=10,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

lda.fit(tf)
#Cálculo de índice de ajuste de los datos
print(lda.perplexity(tf))
print("\nTopics in LDA model:")
print_top_words(lda, diccionario, 10)
# Out:
# 1078.56451553
#
# Topics in LDA model:
# Topic #0: peopl just vote look n't did 's mani support year
# Topic #1: news fake fake news make big number presid time total rate
# Topic #2: https great job thank bring meet america togeth amp trump
# Topic #3: interview enjoy tonight https abc time today year p.m. davidmuir
# Topic #4: n't washington d.c. hack d.c. doe washington russia whi doe n't wonder
# Topic #5: veri great state today https border u.s. build vote wall

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº4: Indage sobre la medida perplexity, ¿Cómo se interpreta el valor obtenido?
# </p></div>

# %%
#Generando algunos gráficos de los resultados
from matplotlib.pylab import hist, show
import seaborn as sns

y=lda.fit_transform(tf)

#distribución de tópicos en todos los documentos
dist = sum(y)/len(docs)
w=np.arange(0,true_k)
plt.bar(w,height=dist,alpha=0.5,tick_label=w)
show()
#distribución de tópicos en el documento 100
plt.bar(w,height=y[100],alpha=0.5,tick_label=w)
show()


#frecuencia de palabras por tópico
n_top_words=10
numo =np.arange(0,n_top_words)
for idx,topic in enumerate(lda.components_):
    d =[]
    s = []
    for i in topic.argsort()[:-n_top_words - 1:-1]:
          s.append(diccionario[i])
          d.append(topic[i])
    
    plt.barh(numo,width=d,alpha=0.5,tick_label=s)
    show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº5: Interprete estos gráficos.
# </p></div>

# %%
#calculando cluster en base al tópico mas frecuente
z=[]
for i in range(len(docs)):
    z.append(np.argmax(y[i]))
plt.scatter(range(297),z,c=z)

#distribución de cluster de acuerdo al cálculo anterior
show()
hist(z,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9)#,density=True)
show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº6: ¿Cómo se comparan estos resultados con los de  Kmeans?
# </p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>Una nueva estimación para algoritmo LDA considerando <a href="https://drive.google.com/open?id=1oSRRvG_W0UaH0l4o9f5ClEyWuGY1j-s0"> Gibbs Sampling</a>, disponible como desarrollo en <a href="https://github.com/lda-project/lda/">lda-project.</a></p>
# </div>

# %%
import lda

model = lda.LDA(n_topics=true_k, n_iter=5000, alpha=0.1, eta=0.1, random_state=3)
model.fit(tf)  # model.fit_transform(X) is also available

topic_word = model.topic_word_  # model.components_ also works
n_top_words=10
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(diccionario)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# INFO:lda:n_documents: 297
# INFO:lda:vocab_size: 705
# INFO:lda:n_words: 2999
# INFO:lda:n_topics: 6
# INFO:lda:n_iter: 5000
# INFO:lda:<0> log likelihood: -28756
# INFO:lda:<10> log likelihood: -20858
# INFO:lda:<20> log likelihood: -20492
# INFO:lda:<30> log likelihood: -20375
# INFO:lda:<40> log likelihood: -20249
# INFO:lda:<50> log likelihood: -20157
# INFO:lda:<60> log likelihood: -20198
# INFO:lda:<70> log likelihood: -20158
# INFO:lda:<80> log likelihood: -20069
# INFO:lda:<90> log likelihood: -19992
# INFO:lda:<100> log likelihood: -20094
# INFO:lda:<110> log likelihood: -19988
# INFO:lda:<120> log likelihood: -20011
# INFO:lda:<130> log likelihood: -20127
# INFO:lda:<140> log likelihood: -20016
# INFO:lda:<150> log likelihood: -20009
# INFO:lda:<160> log likelihood: -19923
# INFO:lda:<170> log likelihood: -20056
# INFO:lda:<180> log likelihood: -20071
# INFO:lda:<190> log likelihood: -20002
# INFO:lda:<200> log likelihood: -19934
# INFO:lda:<210> log likelihood: -19969
# INFO:lda:<220> log likelihood: -20024
# INFO:lda:<230> log likelihood: -19865
# INFO:lda:<240> log likelihood: -19986
# INFO:lda:<250> log likelihood: -19944
# INFO:lda:<260> log likelihood: -19930
# INFO:lda:<270> log likelihood: -20011
# INFO:lda:<280> log likelihood: -20011
# INFO:lda:<290> log likelihood: -19887
# INFO:lda:<300> log likelihood: -19895
# INFO:lda:<310> log likelihood: -20011
# INFO:lda:<320> log likelihood: -19946
# INFO:lda:<330> log likelihood: -19977
# INFO:lda:<340> log likelihood: -19999
# INFO:lda:<350> log likelihood: -19974
# INFO:lda:<360> log likelihood: -19890
# INFO:lda:<370> log likelihood: -20007
# INFO:lda:<380> log likelihood: -19982
# INFO:lda:<390> log likelihood: -19962
# INFO:lda:<400> log likelihood: -20005
# INFO:lda:<410> log likelihood: -19963
# INFO:lda:<420> log likelihood: -19984
# INFO:lda:<430> log likelihood: -19933
# INFO:lda:<440> log likelihood: -19921
# INFO:lda:<450> log likelihood: -19903
# INFO:lda:<460> log likelihood: -19878
# INFO:lda:<470> log likelihood: -19978
# INFO:lda:<480> log likelihood: -19877
# INFO:lda:<490> log likelihood: -19859
# INFO:lda:<500> log likelihood: -19874
# INFO:lda:<510> log likelihood: -19935
# INFO:lda:<520> log likelihood: -19999
# INFO:lda:<530> log likelihood: -19907
# INFO:lda:<540> log likelihood: -19953
# INFO:lda:<550> log likelihood: -19827
# INFO:lda:<560> log likelihood: -19954
# INFO:lda:<570> log likelihood: -19862
# INFO:lda:<580> log likelihood: -19957
# INFO:lda:<590> log likelihood: -19868
# INFO:lda:<600> log likelihood: -19871
# INFO:lda:<610> log likelihood: -19908
# INFO:lda:<620> log likelihood: -19895
# INFO:lda:<630> log likelihood: -19958
# INFO:lda:<640> log likelihood: -19885
# INFO:lda:<650> log likelihood: -19927
# INFO:lda:<660> log likelihood: -19916
# INFO:lda:<670> log likelihood: -19937
# INFO:lda:<680> log likelihood: -19932
# INFO:lda:<690> log likelihood: -19850
# INFO:lda:<700> log likelihood: -19939
# INFO:lda:<710> log likelihood: -19908
# INFO:lda:<720> log likelihood: -19893
# INFO:lda:<730> log likelihood: -19905
# INFO:lda:<740> log likelihood: -19799
# INFO:lda:<750> log likelihood: -19911
# INFO:lda:<760> log likelihood: -19968
# INFO:lda:<770> log likelihood: -19901
# INFO:lda:<780> log likelihood: -19916
# INFO:lda:<790> log likelihood: -19890
# INFO:lda:<800> log likelihood: -19957
# INFO:lda:<810> log likelihood: -19961
# INFO:lda:<820> log likelihood: -19893
# INFO:lda:<830> log likelihood: -19888
# INFO:lda:<840> log likelihood: -19812
# INFO:lda:<850> log likelihood: -19857
# INFO:lda:<860> log likelihood: -19910
# INFO:lda:<870> log likelihood: -19913
# INFO:lda:<880> log likelihood: -19883
# INFO:lda:<890> log likelihood: -19865
# INFO:lda:<900> log likelihood: -19948
# INFO:lda:<910> log likelihood: -19937
# INFO:lda:<920> log likelihood: -19946
# INFO:lda:<930> log likelihood: -19958
# INFO:lda:<940> log likelihood: -19865
# INFO:lda:<950> log likelihood: -19863
# INFO:lda:<960> log likelihood: -19847
# INFO:lda:<970> log likelihood: -19793
# INFO:lda:<980> log likelihood: -19931
# INFO:lda:<990> log likelihood: -20023
# INFO:lda:<1000> log likelihood: -19948
# INFO:lda:<1010> log likelihood: -19888
# INFO:lda:<1020> log likelihood: -19853
# INFO:lda:<1030> log likelihood: -19875
# INFO:lda:<1040> log likelihood: -19961
# INFO:lda:<1050> log likelihood: -19916
# INFO:lda:<1060> log likelihood: -19918
# INFO:lda:<1070> log likelihood: -19935
# INFO:lda:<1080> log likelihood: -19958
# INFO:lda:<1090> log likelihood: -19949
# INFO:lda:<1100> log likelihood: -19855
# INFO:lda:<1110> log likelihood: -19895
# INFO:lda:<1120> log likelihood: -19914
# INFO:lda:<1130> log likelihood: -19940
# INFO:lda:<1140> log likelihood: -19924
# INFO:lda:<1150> log likelihood: -19927
# INFO:lda:<1160> log likelihood: -19931
# INFO:lda:<1170> log likelihood: -19909
# INFO:lda:<1180> log likelihood: -19923
# INFO:lda:<1190> log likelihood: -19982
# INFO:lda:<1200> log likelihood: -19916
# INFO:lda:<1210> log likelihood: -19837
# INFO:lda:<1220> log likelihood: -19873
# INFO:lda:<1230> log likelihood: -19922
# INFO:lda:<1240> log likelihood: -19915
# INFO:lda:<1250> log likelihood: -19939
# INFO:lda:<1260> log likelihood: -19990
# INFO:lda:<1270> log likelihood: -19949
# INFO:lda:<1280> log likelihood: -19848
# INFO:lda:<1290> log likelihood: -19906
# INFO:lda:<1300> log likelihood: -19884
# INFO:lda:<1310> log likelihood: -19863
# INFO:lda:<1320> log likelihood: -19916
# INFO:lda:<1330> log likelihood: -19854
# INFO:lda:<1340> log likelihood: -19817
# INFO:lda:<1350> log likelihood: -19900
# INFO:lda:<1360> log likelihood: -19965
# INFO:lda:<1370> log likelihood: -19929
# INFO:lda:<1380> log likelihood: -19867
# INFO:lda:<1390> log likelihood: -19972
# INFO:lda:<1400> log likelihood: -19932
# INFO:lda:<1410> log likelihood: -19910
# INFO:lda:<1420> log likelihood: -19881
# INFO:lda:<1430> log likelihood: -19859
# INFO:lda:<1440> log likelihood: -19846
# INFO:lda:<1450> log likelihood: -20004
# INFO:lda:<1460> log likelihood: -19853
# INFO:lda:<1470> log likelihood: -19898
# INFO:lda:<1480> log likelihood: -19912
# INFO:lda:<1490> log likelihood: -19950
# INFO:lda:<1500> log likelihood: -19964
# INFO:lda:<1510> log likelihood: -19879
# INFO:lda:<1520> log likelihood: -19880
# INFO:lda:<1530> log likelihood: -19927
# INFO:lda:<1540> log likelihood: -19861
# INFO:lda:<1550> log likelihood: -19905
# INFO:lda:<1560> log likelihood: -20011
# INFO:lda:<1570> log likelihood: -19900
# INFO:lda:<1580> log likelihood: -19884
# INFO:lda:<1590> log likelihood: -19849
# INFO:lda:<1600> log likelihood: -19913
# INFO:lda:<1610> log likelihood: -19899
# INFO:lda:<1620> log likelihood: -19954
# INFO:lda:<1630> log likelihood: -19977
# INFO:lda:<1640> log likelihood: -19977
# INFO:lda:<1650> log likelihood: -19943
# INFO:lda:<1660> log likelihood: -19954
# INFO:lda:<1670> log likelihood: -19935
# INFO:lda:<1680> log likelihood: -19845
# INFO:lda:<1690> log likelihood: -19876
# INFO:lda:<1700> log likelihood: -19948
# INFO:lda:<1710> log likelihood: -19889
# INFO:lda:<1720> log likelihood: -20031
# INFO:lda:<1730> log likelihood: -19908
# INFO:lda:<1740> log likelihood: -19960
# INFO:lda:<1750> log likelihood: -19869
# INFO:lda:<1760> log likelihood: -19926
# INFO:lda:<1770> log likelihood: -19909
# INFO:lda:<1780> log likelihood: -19910
# INFO:lda:<1790> log likelihood: -19886
# INFO:lda:<1800> log likelihood: -19973
# INFO:lda:<1810> log likelihood: -20035
# INFO:lda:<1820> log likelihood: -19922
# INFO:lda:<1830> log likelihood: -19892
# INFO:lda:<1840> log likelihood: -19878
# INFO:lda:<1850> log likelihood: -19880
# INFO:lda:<1860> log likelihood: -19958
# INFO:lda:<1870> log likelihood: -19938
# INFO:lda:<1880> log likelihood: -19826
# INFO:lda:<1890> log likelihood: -19863
# INFO:lda:<1900> log likelihood: -19921
# INFO:lda:<1910> log likelihood: -20038
# INFO:lda:<1920> log likelihood: -19866
# INFO:lda:<1930> log likelihood: -19999
# INFO:lda:<1940> log likelihood: -19833
# INFO:lda:<1950> log likelihood: -19926
# INFO:lda:<1960> log likelihood: -19835
# INFO:lda:<1970> log likelihood: -19962
# INFO:lda:<1980> log likelihood: -20015
# INFO:lda:<1990> log likelihood: -20008
# INFO:lda:<2000> log likelihood: -19968
# INFO:lda:<2010> log likelihood: -19993
# INFO:lda:<2020> log likelihood: -20013
# INFO:lda:<2030> log likelihood: -19886
# INFO:lda:<2040> log likelihood: -19885
# INFO:lda:<2050> log likelihood: -19901
# INFO:lda:<2060> log likelihood: -19882
# INFO:lda:<2070> log likelihood: -19991
# INFO:lda:<2080> log likelihood: -19874
# INFO:lda:<2090> log likelihood: -19876
# INFO:lda:<2100> log likelihood: -19971
# INFO:lda:<2110> log likelihood: -20011
# INFO:lda:<2120> log likelihood: -19894
# INFO:lda:<2130> log likelihood: -19864
# INFO:lda:<2140> log likelihood: -19993
# INFO:lda:<2150> log likelihood: -19942
# INFO:lda:<2160> log likelihood: -20005
# INFO:lda:<2170> log likelihood: -19966
# INFO:lda:<2180> log likelihood: -19946
# INFO:lda:<2190> log likelihood: -19904
# INFO:lda:<2200> log likelihood: -19898
# INFO:lda:<2210> log likelihood: -20019
# INFO:lda:<2220> log likelihood: -19882
# INFO:lda:<2230> log likelihood: -19936
# INFO:lda:<2240> log likelihood: -19945
# INFO:lda:<2250> log likelihood: -19891
# INFO:lda:<2260> log likelihood: -19905
# INFO:lda:<2270> log likelihood: -19861
# INFO:lda:<2280> log likelihood: -19970
# INFO:lda:<2290> log likelihood: -19870
# INFO:lda:<2300> log likelihood: -19918
# INFO:lda:<2310> log likelihood: -19890
# INFO:lda:<2320> log likelihood: -20024
# INFO:lda:<2330> log likelihood: -19966
# INFO:lda:<2340> log likelihood: -19846
# INFO:lda:<2350> log likelihood: -19866
# INFO:lda:<2360> log likelihood: -19865
# INFO:lda:<2370> log likelihood: -19952
# INFO:lda:<2380> log likelihood: -19886
# INFO:lda:<2390> log likelihood: -20047
# INFO:lda:<2400> log likelihood: -20031
# INFO:lda:<2410> log likelihood: -19944
# INFO:lda:<2420> log likelihood: -20009
# INFO:lda:<2430> log likelihood: -19938
# INFO:lda:<2440> log likelihood: -20039
# INFO:lda:<2450> log likelihood: -19921
# INFO:lda:<2460> log likelihood: -19919
# INFO:lda:<2470> log likelihood: -19886
# INFO:lda:<2480> log likelihood: -19928
# INFO:lda:<2490> log likelihood: -19987
# INFO:lda:<2500> log likelihood: -20011
# INFO:lda:<2510> log likelihood: -19966
# INFO:lda:<2520> log likelihood: -19898
# INFO:lda:<2530> log likelihood: -19899
# INFO:lda:<2540> log likelihood: -19906
# INFO:lda:<2550> log likelihood: -19861
# INFO:lda:<2560> log likelihood: -19922
# INFO:lda:<2570> log likelihood: -19952
# INFO:lda:<2580> log likelihood: -20014
# INFO:lda:<2590> log likelihood: -19869
# INFO:lda:<2600> log likelihood: -19987
# INFO:lda:<2610> log likelihood: -19918
# INFO:lda:<2620> log likelihood: -19919
# INFO:lda:<2630> log likelihood: -19893
# INFO:lda:<2640> log likelihood: -19907
# INFO:lda:<2650> log likelihood: -19955
# INFO:lda:<2660> log likelihood: -19871
# INFO:lda:<2670> log likelihood: -19971
# INFO:lda:<2680> log likelihood: -19880
# INFO:lda:<2690> log likelihood: -19782
# INFO:lda:<2700> log likelihood: -19849
# INFO:lda:<2710> log likelihood: -19918
# INFO:lda:<2720> log likelihood: -19971
# INFO:lda:<2730> log likelihood: -19937
# INFO:lda:<2740> log likelihood: -19921
# INFO:lda:<2750> log likelihood: -19925
# INFO:lda:<2760> log likelihood: -19915
# INFO:lda:<2770> log likelihood: -19873
# INFO:lda:<2780> log likelihood: -19897
# INFO:lda:<2790> log likelihood: -19959
# INFO:lda:<2800> log likelihood: -19983
# INFO:lda:<2810> log likelihood: -19926
# INFO:lda:<2820> log likelihood: -19847
# INFO:lda:<2830> log likelihood: -19872
# INFO:lda:<2840> log likelihood: -19898
# INFO:lda:<2850> log likelihood: -19977
# INFO:lda:<2860> log likelihood: -19893
# INFO:lda:<2870> log likelihood: -19864
# INFO:lda:<2880> log likelihood: -19916
# INFO:lda:<2890> log likelihood: -19825
# INFO:lda:<2900> log likelihood: -19872
# INFO:lda:<2910> log likelihood: -19872
# INFO:lda:<2920> log likelihood: -19882
# INFO:lda:<2930> log likelihood: -19969
# INFO:lda:<2940> log likelihood: -19892
# INFO:lda:<2950> log likelihood: -19935
# INFO:lda:<2960> log likelihood: -19899
# INFO:lda:<2970> log likelihood: -19929
# INFO:lda:<2980> log likelihood: -19884
# INFO:lda:<2990> log likelihood: -20060
# INFO:lda:<3000> log likelihood: -19909
# INFO:lda:<3010> log likelihood: -19843
# INFO:lda:<3020> log likelihood: -19828
# INFO:lda:<3030> log likelihood: -19857
# INFO:lda:<3040> log likelihood: -19889
# INFO:lda:<3050> log likelihood: -19948
# INFO:lda:<3060> log likelihood: -19888
# INFO:lda:<3070> log likelihood: -20009
# INFO:lda:<3080> log likelihood: -19911
# INFO:lda:<3090> log likelihood: -19808
# INFO:lda:<3100> log likelihood: -19929
# INFO:lda:<3110> log likelihood: -19935
# INFO:lda:<3120> log likelihood: -19846
# INFO:lda:<3130> log likelihood: -19989
# INFO:lda:<3140> log likelihood: -19910
# INFO:lda:<3150> log likelihood: -19832
# INFO:lda:<3160> log likelihood: -19911
# INFO:lda:<3170> log likelihood: -19965
# INFO:lda:<3180> log likelihood: -19893
# INFO:lda:<3190> log likelihood: -19884
# INFO:lda:<3200> log likelihood: -19871
# INFO:lda:<3210> log likelihood: -19921
# INFO:lda:<3220> log likelihood: -19862
# INFO:lda:<3230> log likelihood: -19881
# INFO:lda:<3240> log likelihood: -19903
# INFO:lda:<3250> log likelihood: -19915
# INFO:lda:<3260> log likelihood: -19972
# INFO:lda:<3270> log likelihood: -19891
# INFO:lda:<3280> log likelihood: -19928
# INFO:lda:<3290> log likelihood: -19909
# INFO:lda:<3300> log likelihood: -19821
# INFO:lda:<3310> log likelihood: -19948
# INFO:lda:<3320> log likelihood: -19937
# INFO:lda:<3330> log likelihood: -19955
# INFO:lda:<3340> log likelihood: -19786
# INFO:lda:<3350> log likelihood: -19902
# INFO:lda:<3360> log likelihood: -19890
# INFO:lda:<3370> log likelihood: -19915
# INFO:lda:<3380> log likelihood: -19869
# INFO:lda:<3390> log likelihood: -19884
# INFO:lda:<3400> log likelihood: -19790
# INFO:lda:<3410> log likelihood: -19947
# INFO:lda:<3420> log likelihood: -19899
# INFO:lda:<3430> log likelihood: -19893
# INFO:lda:<3440> log likelihood: -19889
# INFO:lda:<3450> log likelihood: -19945
# INFO:lda:<3460> log likelihood: -19859
# INFO:lda:<3470> log likelihood: -19915
# INFO:lda:<3480> log likelihood: -19843
# INFO:lda:<3490> log likelihood: -19912
# INFO:lda:<3500> log likelihood: -19924
# INFO:lda:<3510> log likelihood: -19939
# INFO:lda:<3520> log likelihood: -19903
# INFO:lda:<3530> log likelihood: -19967
# INFO:lda:<3540> log likelihood: -19873
# INFO:lda:<3550> log likelihood: -19928
# INFO:lda:<3560> log likelihood: -19938
# INFO:lda:<3570> log likelihood: -19847
# INFO:lda:<3580> log likelihood: -19849
# INFO:lda:<3590> log likelihood: -19806
# INFO:lda:<3600> log likelihood: -19840
# INFO:lda:<3610> log likelihood: -19879
# INFO:lda:<3620> log likelihood: -19916
# INFO:lda:<3630> log likelihood: -19905
# INFO:lda:<3640> log likelihood: -19850
# INFO:lda:<3650> log likelihood: -19884
# INFO:lda:<3660> log likelihood: -19852
# INFO:lda:<3670> log likelihood: -19876
# INFO:lda:<3680> log likelihood: -19923
# INFO:lda:<3690> log likelihood: -19852
# INFO:lda:<3700> log likelihood: -19908
# INFO:lda:<3710> log likelihood: -19936
# INFO:lda:<3720> log likelihood: -19989
# INFO:lda:<3730> log likelihood: -19931
# INFO:lda:<3740> log likelihood: -19817
# INFO:lda:<3750> log likelihood: -19816
# INFO:lda:<3760> log likelihood: -19872
# INFO:lda:<3770> log likelihood: -19943
# INFO:lda:<3780> log likelihood: -19931
# INFO:lda:<3790> log likelihood: -19898
# INFO:lda:<3800> log likelihood: -19953
# INFO:lda:<3810> log likelihood: -19862
# INFO:lda:<3820> log likelihood: -19873
# INFO:lda:<3830> log likelihood: -19937
# INFO:lda:<3840> log likelihood: -19905
# INFO:lda:<3850> log likelihood: -19904
# INFO:lda:<3860> log likelihood: -19883
# INFO:lda:<3870> log likelihood: -19913
# INFO:lda:<3880> log likelihood: -19900
# INFO:lda:<3890> log likelihood: -19881
# INFO:lda:<3900> log likelihood: -19862
# INFO:lda:<3910> log likelihood: -19870
# INFO:lda:<3920> log likelihood: -19879
# INFO:lda:<3930> log likelihood: -19900
# INFO:lda:<3940> log likelihood: -19865
# INFO:lda:<3950> log likelihood: -19924
# INFO:lda:<3960> log likelihood: -19884
# INFO:lda:<3970> log likelihood: -20012
# INFO:lda:<3980> log likelihood: -20009
# INFO:lda:<3990> log likelihood: -19993
# INFO:lda:<4000> log likelihood: -19875
# INFO:lda:<4010> log likelihood: -19982
# INFO:lda:<4020> log likelihood: -19820
# INFO:lda:<4030> log likelihood: -19877
# INFO:lda:<4040> log likelihood: -19841
# INFO:lda:<4050> log likelihood: -19977
# INFO:lda:<4060> log likelihood: -19872
# INFO:lda:<4070> log likelihood: -19953
# INFO:lda:<4080> log likelihood: -19914
# INFO:lda:<4090> log likelihood: -19973
# INFO:lda:<4100> log likelihood: -19943
# INFO:lda:<4110> log likelihood: -19908
# INFO:lda:<4120> log likelihood: -19953
# INFO:lda:<4130> log likelihood: -19900
# INFO:lda:<4140> log likelihood: -19963
# INFO:lda:<4150> log likelihood: -19873
# INFO:lda:<4160> log likelihood: -19892
# INFO:lda:<4170> log likelihood: -19881
# INFO:lda:<4180> log likelihood: -19962
# INFO:lda:<4190> log likelihood: -19873
# INFO:lda:<4200> log likelihood: -19897
# INFO:lda:<4210> log likelihood: -19891
# INFO:lda:<4220> log likelihood: -19888
# INFO:lda:<4230> log likelihood: -19892
# INFO:lda:<4240> log likelihood: -19860
# INFO:lda:<4250> log likelihood: -19966
# INFO:lda:<4260> log likelihood: -19960
# INFO:lda:<4270> log likelihood: -19914
# INFO:lda:<4280> log likelihood: -19856
# INFO:lda:<4290> log likelihood: -19924
# INFO:lda:<4300> log likelihood: -19929
# INFO:lda:<4310> log likelihood: -19844
# INFO:lda:<4320> log likelihood: -19830
# INFO:lda:<4330> log likelihood: -19943
# INFO:lda:<4340> log likelihood: -19909
# INFO:lda:<4350> log likelihood: -20019
# INFO:lda:<4360> log likelihood: -19937
# INFO:lda:<4370> log likelihood: -19952
# INFO:lda:<4380> log likelihood: -19872
# INFO:lda:<4390> log likelihood: -19883
# INFO:lda:<4400> log likelihood: -19947
# INFO:lda:<4410> log likelihood: -19903
# INFO:lda:<4420> log likelihood: -19907
# INFO:lda:<4430> log likelihood: -19912
# INFO:lda:<4440> log likelihood: -19820
# INFO:lda:<4450> log likelihood: -19953
# INFO:lda:<4460> log likelihood: -19942
# INFO:lda:<4470> log likelihood: -19872
# INFO:lda:<4480> log likelihood: -19935
# INFO:lda:<4490> log likelihood: -19875
# INFO:lda:<4500> log likelihood: -19911
# INFO:lda:<4510> log likelihood: -19898
# INFO:lda:<4520> log likelihood: -19860
# INFO:lda:<4530> log likelihood: -19939
# INFO:lda:<4540> log likelihood: -19963
# INFO:lda:<4550> log likelihood: -19843
# INFO:lda:<4560> log likelihood: -19889
# INFO:lda:<4570> log likelihood: -19835
# INFO:lda:<4580> log likelihood: -19873
# INFO:lda:<4590> log likelihood: -19926
# INFO:lda:<4600> log likelihood: -19863
# INFO:lda:<4610> log likelihood: -19892
# INFO:lda:<4620> log likelihood: -19953
# INFO:lda:<4630> log likelihood: -19870
# INFO:lda:<4640> log likelihood: -19899
# INFO:lda:<4650> log likelihood: -19910
# INFO:lda:<4660> log likelihood: -19929
# INFO:lda:<4670> log likelihood: -19855
# INFO:lda:<4680> log likelihood: -19863
# INFO:lda:<4690> log likelihood: -19918
# INFO:lda:<4700> log likelihood: -19910
# INFO:lda:<4710> log likelihood: -19888
# INFO:lda:<4720> log likelihood: -19838
# INFO:lda:<4730> log likelihood: -19866
# INFO:lda:<4740> log likelihood: -19905
# INFO:lda:<4750> log likelihood: -19916
# INFO:lda:<4760> log likelihood: -19939
# INFO:lda:<4770> log likelihood: -19854
# INFO:lda:<4780> log likelihood: -19932
# INFO:lda:<4790> log likelihood: -20002
# INFO:lda:<4800> log likelihood: -19859
# INFO:lda:<4810> log likelihood: -19841
# INFO:lda:<4820> log likelihood: -19843
# INFO:lda:<4830> log likelihood: -19953
# INFO:lda:<4840> log likelihood: -19945
# INFO:lda:<4850> log likelihood: -19890
# INFO:lda:<4860> log likelihood: -19852
# INFO:lda:<4870> log likelihood: -19972
# INFO:lda:<4880> log likelihood: -19843
# INFO:lda:<4890> log likelihood: -19947
# INFO:lda:<4900> log likelihood: -19989
# INFO:lda:<4910> log likelihood: -19929
# INFO:lda:<4920> log likelihood: -19845
# INFO:lda:<4930> log likelihood: -19903
# INFO:lda:<4940> log likelihood: -19903
# INFO:lda:<4950> log likelihood: -19898
# INFO:lda:<4960> log likelihood: -19855
# INFO:lda:<4970> log likelihood: -19840
# INFO:lda:<4980> log likelihood: -19857
# INFO:lda:<4990> log likelihood: -19925
# INFO:lda:<4999> log likelihood: -19994
# Topic 0: media hack did like report news fake whi fake news total
# Topic 1: https thank join interview thankyoutour2016 watch ticket https alabama ticket tonight
# Topic 2: n't just state vote elect john wrong doe rate know
# Topic 3: job u.s. trump mexico meet support great today new amp
# Topic 4: great time make america peopl presid job mani world amp
# Topic 5: https year veri rt look realdonaldtrump happi trump 's look forward

# %%
plt.plot(model.loglikelihoods_[5:])

# %%
#Generando algunos gráficos de los resultados
from matplotlib.pylab import hist, show

y=model.doc_topic_
#distribución de tópicos en todos los documentos
dist = sum(y)/len(docs)
w=np.arange(0,true_k)
plt.bar(w,height=dist,alpha=0.5,tick_label=w)
show()

#distribución de tópicos en el documento 100
plt.bar(w,height=y[100],alpha=0.5,tick_label=w)
show()

#frecuencia de palabras por tópico
n_top_words=10
numo =np.arange(0,n_top_words)

for idx,topic in enumerate(model.topic_word_):
    d =[]
    s = []
    for i in topic.argsort()[:-n_top_words - 1:-1]:
          s.append(diccionario[i])
          d.append(topic[i])
    
    plt.barh(numo,width=d,alpha=0.5,tick_label=s)
    show()

# %%
#calculando cluster en base al tópico mas frecuente
z=[]
for i in range(len(docs)):
    z.append(np.argmax(y[i]))
plt.scatter(range(297),z,c=z)
show()

#distribución de cluster de acuerdo a la definición anterior
hist(z,bins=np.arange(-0.5,5.6,1),alpha=0.5,rwidth=0.9)#,density=True)
show()

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #c5ddf6;">
# <p>Pregunta Nº7: ¿Cómo se comparan estos resultados con los anteriores? ¿Qué puede decir de la convergencia de la estimación en este caso?
# </p></div>

# %% [markdown]
# <div style="border: 2px solid #1c75c8; background-color: #F8B4B4">
# <p>Considerando este ejemplo realice el análisis de tópicos del set de datos en speeches.csv.
# Comente sus hallazgos </p> </div>
